# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Importing files

# %%
data = pd.read_csv(r'C:\Users\user\Desktop\Excel Full Course\docs\Ecommerce Purchases')
data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# # #Checking data types

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# # Checking for duplicates

# %%
data.duplicated().any()
# Out:
# False

# %% [markdown]
# # Checking for null values

# %%
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# ## Purchase price by country

# %%
grouped=data.groupby('Company').sum().reset_index()
company_purchase = grouped[['Company','Purchase Price']].sort_values('Purchase Price', ascending = False)
company_purchase.head(10)
# Out:
#              Company  Purchase Price
# 805        Brown Ltd          796.38
# 8303    Williams LLC          723.63
# 7166       Smith LLC          637.92
# 7168       Smith PLC          601.37
# 3782     Johnson Ltd          600.61
# 7164     Smith Group          592.54
# 3783     Johnson PLC          567.33
# 1724  Davis and Sons          560.09
# 802      Brown Group          522.72
# 803        Brown Inc          520.41

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %% [markdown]
# ## Statistics of purchase price

# %%
data['Purchase Price'].describe()
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %%
groupe=data.groupby('Job').sum().reset_index()
companypurchase = groupe[['Job','Purchase Price']].sort_values('Purchase Price', ascending = False)
companypurchase.head(10)
# Out:
#                                    Job  Purchase Price
# 158                          Dietitian         1605.30
# 325                             Lawyer         1603.85
# 473                 Purchasing manager         1577.97
# 589                     Therapist, art         1526.31
# 101            Clinical cytogeneticist         1495.92
# 489  Research officer, political party         1488.79
# 151                Designer, jewellery         1482.20
# 312      Interior and spatial designer         1466.20
# 384                   Network engineer         1421.73
# 531                  Social researcher         1416.34

# %% [markdown]
# ## Number of companies

# %%
len(data['Company'].unique())
# Out:
# 8653

# %% [markdown]
# ## Number of professionals

# %%
len(data['Job'].unique())
# Out:
# 623

# %%
data[data['Language'].str.contains('fr')]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9951                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# ## Number of customers that speaks french

# %%
len(data[data['Language'].str.contains('fr')])
# Out:
# 1097

# %%
data[data['Job'].str.contains('Engineer',case= False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
Address = data[data['IP Address']== '132.207.160.22']
Address['Email']
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %% [markdown]
# # Number of transactions made in 2020

# %% [markdown]
# def year():
#     count= 0
#     for date in data['CC Exp Date']:
#         if date.split('/')[1]== '20':
#             count +=1
#     print(count)

# %%
year()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 year()
#
# NameError: name 'year' is not defined

# %%
def year():
    
    for date in data['CC Exp Date']:
        if date.split('/')[1]== '20':
            print(date)

# %%
len(data[data['CC Exp Date'].apply(lambda x: x[3:]=="20")])
# Out:
# 988

# %%
Glist= []
for mail in data['Email']:
    Glist.append(mail.split('@')[1])

# %%
data['temp'] = Glist

# %% [markdown]
# ## List of email type used

# %%
data['temp'].value_counts().head(10)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# brown.com         29
# johnson.com       29
# davis.com         25
# jones.com         25
# martinez.com      19
# Name: temp, dtype: int64
